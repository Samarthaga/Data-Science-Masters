# %%
## Ans 1: when some of the information not stored in the data is known as missing values 
## it is important ro handle as if the model is not trained on missing values then predictionof the test will vary and gets impacted 
## Algirithims not affected are not related results of the test who are independent and does not have any prediction

# %%
## Ans 2,
## dropna , dropna(axis=1),mean and median values
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna(axis=1)
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %%
df['age_mean']=df['age'].fillna(df['age'].mean())

# %%
df[['age_mean','age']]
# Out:
#       age_mean   age
# 0    22.000000  22.0
# 1    38.000000  38.0
# 2    26.000000  26.0
# 3    35.000000  35.0
# 4    35.000000  35.0
# ..         ...   ...
# 886  27.000000  27.0
# 887  19.000000  19.0
# 888  29.699118   NaN
# 889  26.000000  26.0
# 890  32.000000  32.0
#
# [891 rows x 2 columns]

# %%
df['age_median']=df['age'].fillna(df['age'].median())

# %%
df[['age_median','age_mean','age']]
# Out:
#      age_median   age_mean   age
# 0          22.0  22.000000  22.0
# 1          38.0  38.000000  38.0
# 2          26.0  26.000000  26.0
# 3          35.0  35.000000  35.0
# 4          35.0  35.000000  35.0
# ..          ...        ...   ...
# 886        27.0  27.000000  27.0
# 887        19.0  19.000000  19.0
# 888        28.0  29.699118   NaN
# 889        26.0  26.000000  26.0
# 890        32.0  32.000000  32.0
#
# [891 rows x 3 columns]

# %%
## Ans 3:  Imbalanced data is a dataset where if binomial results are considered and if the data have majority and have less minority the data predictions will be trained 95% for majority and very less for minority 
##  the model fails to identify the minority class yet the accuracy score of the model will be 95%. Thus our traditional approach of classification and model accuracy calculation is not useful in the case of the imbalanced dataset

# %%
## Ans 4. Upsampling is the process of increasing the data of minority and downsampling is the process of decreasing the data of majority .
## in data of sales of insurance of life and vehicle if data have majority data of life and minority as insurance

# %%
## Ans 5: SMOTE is an algorithm that performs data augmentation by creating synthetic data points based on the original data points. SMOTE can be seen as an advanced version of oversampling, or as a specific algorithm for data augmentation

# %%
## Ans 6: An outlier is an observation that lies an abnormal distance from other values in a random sample from a population. In a sense, this definition leaves it up to the analyst (or a consensus process) to decide what will be considered abnormal.

# %%
## Ans 7: we can do interpolation , cubic interpolation and polyinterpolation methods to analyse the data

# %%
## Ans 8 : Some strategies for MCAR and MAR are calculating mean and median of the observations for the resolution of the data 
## as said MCAR might have occured due to some error in machine or form mean will suffice the data and if the data is missing with the data observed due to some filling cirteria median can also be computed

# %%
## Ans 9 : UPsampling and donwnsampling are the methods we can use for imbalanced data or SMOTE can also be used for such data types .

# %%
## Ans 10. for data holding majority as satisfied and minority as unsatisfied we can downsize the data from majority to len of minority

# %%
## Ans 11 : Linear interpolation technique can be used for the said case of low occurences and for estimation the occurances of rare envents 
## usually 5 number summary and boxplot for determining the outliers in low frequecy data
