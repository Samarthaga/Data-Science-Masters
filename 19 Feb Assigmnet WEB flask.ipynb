# %%
## Ans 1- flask is micro web framework written in python
## Advantages :
## Scalable , easy to operate ,Flexible , Lightweight

# %% [markdown]
# ## Ans 2 ![image.png](attachment:b9e470c9-2777-48bc-9bd0-bd764d84bc85.png)

# %%
## Ans 3- App Routing means mapping the URLs to a specific function that will handle the logic for that URL
## URLs to help users remember the URLs and make navigation simpler.

# %% [markdown]
# ## Ans 4.![image.png](attachment:47c05d22-f4c3-4417-b270-47fb11d0e4e5.png)

# %% [markdown]
# ## ![image.png](attachment:74853f14-364d-4e0a-9e0c-54386c47e57c.png)
