# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('winequality-red (1).csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# we will suppose the quality as target 
plt.figure(figsize=(5,4))
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
# check for duplicates 
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality
# 4         9.4        5
# 11       10.5        5
# 27        9.5        5
# 40       10.5        5
# 65       10.9        5
# ...       ...      ...
# 1563     10.1        5
# 1564     10.1        5
# 1567     10.1        5
# 1581     11.3        5
# 1596     11.0        6
#
# [240 rows x 12 columns]

# %%
df.shape
# Out:
# (1599, 12)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (1359, 12)

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 5         9.4
# ...       ...
# 1593      9.5
# 1594     10.5
# 1595     11.2
# 1597     10.2
# 1598     11.0
#
# [1359 rows x 11 columns]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 5      9.4        5

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=12)

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.35376931, -1.30626009, -0.10719318, ...,  0.12443142,
#         -0.68165575, -0.10569495],
#        [ 2.43446605, -0.75397567,  1.12533943, ..., -1.52261956,
#          0.90152168, -0.10569495],
#        [ 2.03868026, -0.80920411,  1.12533943, ..., -0.95248653,
#         -0.28586139, -0.10569495],
#        ...,
#        [-1.07106518,  0.18490784, -0.62074844, ...,  0.12443142,
#         -0.34240344,  0.08145645],
#        [-1.18414683,  0.68196382, -1.08294817, ...,  1.64478616,
#         -0.68165575,  1.4383041 ],
#        [-0.84490187,  1.5656189 , -1.1343037 , ...,  1.26469748,
#         -0.00315113,  0.36218355]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=3)

# %%
X_train=pca.fit_transform(X_train)

# %%
X_test=pca.transform(X_test)

# %%
pca.components_
# Out:
# array([[ 4.84576923e-01, -2.37011294e-01,  4.61924648e-01,
#          1.29896752e-01,  2.09625175e-01, -3.82020757e-02,
#          2.90724358e-02,  4.01473879e-01, -4.41612256e-01,
#          2.42739950e-01, -1.31873590e-01],
#        [-1.15260213e-01,  2.64765336e-01, -1.44420464e-01,
#          2.30834507e-01,  1.30190484e-01,  5.32849467e-01,
#          5.91286307e-01,  2.06476197e-01,  1.27221740e-04,
#         -1.06105873e-02, -3.86302895e-01],
#        [-1.33657360e-01, -4.69844531e-01,  2.50668793e-01,
#          2.44755234e-02, -5.05465157e-02,  4.14059367e-01,
#          3.06345010e-01, -3.64963993e-01,  2.74816128e-02,
#          2.92873931e-01,  4.58662689e-01]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.28316932, 0.17343077, 0.14140068])

# %%
import numpy as np
import matplotlib.pyplot as plt


from sklearn import decomposition
from sklearn import datasets

# unused but required import for doing 3d projections with matplotlib < 3.2
import mpl_toolkits.mplot3d  # noqa: F401

np.random.seed(5)

iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()

ax = fig.add_subplot(111, projection="3d", elev=48, azim=134)
ax.set_position([0, 0, 0.95, 1])


plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

for name, label in [("Setosa", 0), ("Versicolour", 1), ("Virginica", 2)]:
    ax.text3D(
        X[y == label, 0].mean(),
        X[y == label, 1].mean() + 1.5,
        X[y == label, 2].mean(),
        name,
        horizontalalignment="center",
        bbox=dict(alpha=0.5, edgecolor="w", facecolor="w"),
    )
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral, edgecolor="k")

ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.zaxis.set_ticklabels([])

plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
y_pred=classifier.predict(X_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.5441176470588235
# [[  0   1   3   1   0   0]
#  [  1   0   8   5   0   0]
#  [  1   0 128  42   2   0]
#  [  0   1  55  86  17   0]
#  [  0   0   9  32   8   1]
#  [  0   0   0   2   5   0]]
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00        14
#            5       0.63      0.74      0.68       173
#            6       0.51      0.54      0.53       159
#            7       0.25      0.16      0.20        50
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.54       408
#    macro avg       0.23      0.24      0.23       408
# weighted avg       0.50      0.54      0.52       408

# %%
parameters={
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_features':['sqrt', 'log2', None]

}

# %%
cv=GridSearchCV(classifier,param_grid=parameters,cv=5,verbose=3,refit=True)

# %%
cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .criterion=gini, max_features=sqrt;, score=0.492 total time=   0.3s
# [CV 2/5] END .criterion=gini, max_features=sqrt;, score=0.532 total time=   0.3s
# [CV 3/5] END .criterion=gini, max_features=sqrt;, score=0.521 total time=   0.3s
# [CV 4/5] END .criterion=gini, max_features=sqrt;, score=0.537 total time=   0.3s
# [CV 5/5] END .criterion=gini, max_features=sqrt;, score=0.495 total time=   0.3s
# [CV 1/5] END .criterion=gini, max_features=log2;, score=0.539 total time=   0.3s
# [CV 2/5] END .criterion=gini, max_features=log2;, score=0.521 total time=   0.3s
# [CV 3/5] END .criterion=gini, max_features=log2;, score=0.521 total time=   0.3s
# [CV 4/5] END .criterion=gini, max_features=log2;, score=0.521 total time=   0.3s
# [CV 5/5] END .criterion=gini, max_features=log2;, score=0.489 total time=   0.3s
# [CV 1/5] END .criterion=gini, max_features=None;, score=0.435 total time=   0.4s
# [CV 2/5] END .criterion=gini, max_features=None;, score=0.537 total time=   0.4s
# [CV 3/5] END .criterion=gini, max_features=None;, score=0.521 total time=   0.4s
# [CV 4/5] END .criterion=gini, max_features=None;, score=0.511 total time=   0.4s
# [CV 5/5] END .criterion=gini, max_features=None;, score=0.521 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_features=sqrt;, score=0.539 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_features=sqrt;, score=0.542 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_features=sqrt;, score=0.500 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_features=sqrt;, score=0.537 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_features=sqrt;, score=0.511 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_features=log2;, score=0.497 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_features=log2;, score=0.542 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_features=log2;, score=0.526 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_features=log2;, score=0.532 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_features=log2;, score=0.489 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_features=None;, score=0.455 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_features=None;, score=0.547 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_features=None;, score=0.516 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_features=None;, score=0.505 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_features=None;, score=0.474 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_features=sqrt;, score=0.518 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_features=sqrt;, score=0.553 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_features=sqrt;, score=0.511 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_features=sqrt;, score=0.511 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_features=sqrt;, score=0.479 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_features=log2;, score=0.518 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_features=log2;, score=0.516 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_features=log2;, score=0.479 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_features=log2;, score=0.537 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_features=log2;, score=0.489 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_features=None;, score=0.466 total time=   0.5s
# [CV 2/5] END criterion=log_loss, max_features=None;, score=0.521 total time=   0.5s
# [CV 3/5] END criterion=log_loss, max_features=None;, score=0.511 total time=   0.5s
# [CV 4/5] END criterion=log_loss, max_features=None;, score=0.479 total time=   0.5s
# [CV 5/5] END criterion=log_loss, max_features=None;, score=0.489 total time=   0.5s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', None]},
#              verbose=3)

# %%
y_pred_n=cv.predict(X_test)

# %%
cv.best_params_
# Out:
# {'criterion': 'entropy', 'max_features': 'sqrt'}

# %%
classifier=RandomForestClassifier(criterion='entropy',max_features='sqrt')

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
y_pred=classifier.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.5294117647058824
# [[  0   1   2   2   0   0]
#  [  0   0  10   4   0   0]
#  [  0   0 123  47   3   0]
#  [  0   1  60  83  15   0]
#  [  0   0   8  32  10   0]
#  [  0   0   0   2   5   0]]
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00        14
#            5       0.61      0.71      0.65       173
#            6       0.49      0.52      0.50       159
#            7       0.30      0.20      0.24        50
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.53       408
#    macro avg       0.23      0.24      0.23       408
# weighted avg       0.48      0.53      0.50       408
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
