# %%
pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bokeh.io

# %%
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

# %%
p=figure(title='test flower')
p.xaxis.axis_label ='petal_length'
p.yaxis.axis_label='petal_width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="481f13f5-b203-464b-a1f6-e05d743e9267" data-root-id="1002"></div>

# %%
p=figure(title='test flower')
p.xaxis.axis_label ='petal_length'
p.yaxis.axis_label='petal_width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="41b372b3-a982-41b9-89dc-8a8444af5943" data-root-id="1222"></div>

# %%
x=[3,4,5,6,7]
y=[4,5,6,7,4]
output_file('line.html')
p=figure(title='linr graph')
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="96e561a0-e079-455c-9c46-769ba895db52" data-root-id="1472"></div>

# %%
x=[3,4,5,6,7]
y=[4,5,6,7,4]
output_file('line.html')
p=figure(title='linr graph')
p.scatter(x,y,size=20,fill_color='red',legend_label='this is my data points')
show(p)
# Out:
#   <div class="bk-root" id="60d81757-83a8-437f-a5eb-ea395af5aa9a" data-root-id="2884"></div>

# %% [markdown]
# Assignment 5 March

# %% [markdown]
# Ans 1
#
# ```
# # This is formatted as code
# ```

# %%
x=[3,4,5,6,7]
y=[4,5,6,7,4]
output_file('line.html')
p=figure(title='linr graph')
p.scatter(x,y,size=20,fill_color='red',legend_label='this is my data points')
show(p)
# Out:
#   <div class="bk-root" id="a1ff1cd7-ce7f-4ff5-b665-8b5ab46f87eb" data-root-id="3206"></div>

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Ans 2
# a vectorized graphical shape or marker that is used to represent your data

# %%
fig = figure(plot_width = 200, plot_height = 400)
fig.vbar(x = [1,2,3], width = 0.5, bottom = 0, top = [2,4,6], color = "Cyan")
output_file('bar.html')
show(fig)
# Out:
#   <div class="bk-root" id="8e08747b-1d11-4d48-bd48-d3218af8fad3" data-root-id="3538"></div>

# %% [markdown]
# Ans 3

# %%
x1 = [1, 3, 4, 5, 6]
x2 = [5, 3, 8, 1, 8]
y1 = [6, 7, 8, 9, 4]
y2 = [3, 4, 5, 6, 7]

# %%
p = figure(title="Drawing multiple lines",
           x_axis_label="X-Axis", y_axis_label="Y-Axis")

# %%
p.line(x1, y1, legend_label="line 1", line_color="red", line_width=1)
p.line(x2, y2, legend_label="line 2", line_color="blue", line_width=1)
p.line(x1, y2, legend_label="line 3", line_color="black", line_width=1)
show(p)
# Out:
#   <div class="bk-root" id="e8244329-133c-4208-9205-9340ab68462c" data-root-id="3886"></div>

# %% [markdown]
# Ans 4: Bokeh server makes it easy to create interactive web applications that connect front-end UI events to running Python code.

# %%
from bokeh.plotting import figure
from bokeh.resources import CDN
from bokeh.embed import file_html

plot = figure()
plot.circle([1,2], [3,4])

html = file_html(plot, CDN, "my plot")
